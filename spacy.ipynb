# %% [markdown]
# <a href="https://colab.research.google.com/github/Nirmal3335/NLP/blob/spacy/spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SPACY INSTALL

# %%
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 108.0 MB/s  0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

for token in doc:
  print(token.text, token.pos_, token.dep_)
# Out:
# Apple PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.K. PROPN nsubj
# startup VERB ccomp
# for ADP prep
# $ SYM quantmod
# 1 NUM compound
# billion NUM pobj

# %% [markdown]
# **Tokenziation**

# %%
text = '''"Let's" go to N.Y.!"'''

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(text)

# %%
for token in doc:
  print(token.text)
# Out:
# "
# Let
# 's
# "
# go
# to
# N.Y.
# !
# "

# %%
text2 = "Ram kumar is my manager is lead product support team, he salary is $10,000."

doc2 = nlp(text2)

for token in doc2:
  print(token.text)
# Out:
# Ram
# kumar
# is
# my
# manager
# is
# lead
# product
# support
# team
# ,
# he
# salary
# is
# $
# 10,000
# .

# %% [markdown]
# # Part of speech (POS)

# %%
# !pip install beautifultable

# %%
from beautifultable import BeautifulTable

table = BeautifulTable()

# %%
text = "Apple is looking at buying U.K. startup for $1 billion"
doc = nlp(text)

table.columns.header = ["TEXT", "POS", "TAG", "DEP", "LEMMA", "SHAPE", "ALPHA", "STOP"]

for token in doc:
  table.rows.append([token.text, token.pos_, token.tag_, token.dep_, token.lemma_, token.shape_, token.is_alpha, token.is_stop])

print(table)
# Out:
# +---------+-------+-----+----------+---------+-------+-------+------+
# |  TEXT   |  POS  | TAG |   DEP    |  LEMMA  | SHAPE | ALPHA | STOP |
# +---------+-------+-----+----------+---------+-------+-------+------+
# |  Apple  | PROPN | NNP |  nsubj   |  Apple  | Xxxxx |   1   |  0   |
# +---------+-------+-----+----------+---------+-------+-------+------+
# |   is    |  AUX  | VBZ |   aux    |   be    |  xx   |   1   |  1   |
# +---------+-------+-----+----------+---------+-------+-------+------+
# | looking | VERB  | VBG |   ROOT   |  look   | xxxx  |   1   |  0   |
# +---------+-------+-----+----------+---------+-------+-------+------+
# |   at    |  ADP  | IN  |   prep   |   at    |  xx   |   1   |  1   |
# +---------+-------+-----+----------+---------+-------+-------+------+
# | buying  | VERB  | VBG |  pcomp   |   buy   | xxxx  |   1   |  0   |
# +---------+-------+-----+----------+---------+-------+-------+------+
# ...

# %%
from spacy import displacy

# %%
options = {"compact":True, "distance": 150, "bg":"#0095b6", "color":"#DDDDDD", "font":"Source Sans Pro"}
displacy.render(doc, style="dep", jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c7396e8de3f948279b77c4e2ecf5134c-0" class="displacy" width="1700" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #DDDDDD; background: #0095b6; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
# ...

# %% [markdown]
# # Sentence Boundary Detection

# %%
para = "If we are unable to complete our initial business combination within 33 months from the closing of this offering, unless we extend such period via sponsor commitment, we will redeem 100% of the public shares at a per-share price equal to the aggregate amount on deposit in the trust account, including interest earned thereon (less taxes payable and up to $65,000 of interest to pay dissolution expenses), divided by the number of then outstanding public shares. Shareholders could face liability if distributions are deemed unlawful."

# %%
doc = nlp(para)

# %%
list(doc)
# Out:
# [If,
#  we,
#  are,
#  unable,
#  to,
#  complete,
#  our,
#  initial,
#  business,
#  combination,
#  within,
#  33,
#  months,
#  from,
#  the,
#  closing,
#  of,
#  this,
#  offering,
#  ,,
#  unless,
#  we,
#  extend,
#  such,
#  period,
#  via,
#  sponsor,
#  commitment,
#  ,,
#  we,
#  will,
#  redeem,
#  100,
#  %,
#  of,
#  the,
#  public,
#  shares,
#  at,
#  a,
#  per,
#  -,
#  share,
#  price,
#  equal,
#  to,
#  the,
#  aggregate,
#  amount,
#  on,
#  deposit,
#  in,
#  the,
#  trust,
#  account,
#  ,,
#  including,
#  interest,
#  earned,
#  thereon,
#  (,
#  less,
#  taxes,
#  payable,
#  and,
#  up,
#  to,
#  $,
#  65,000,
#  of,
#  interest,
#  to,
#  pay,
#  dissolution,
#  expenses,
#  ),
#  ,,
#  divided,
#  by,
#  the,
#  number,
#  of,
#  then,
#  outstanding,
#  public,
#  shares,
#  .,
#  Shareholders,
#  could,
#  face,
#  liability,
#  if,
#  distributions,
#  are,
#  deemed,
#  unlawful,
#  .]

# %%
sents = list(doc.sents)

len(sents)
# Out:
# 2

# %%
for sent in sents:
  print(sent)
# Out:
# If we are unable to complete our initial business combination within 33 months from the closing of this offering, unless we extend such period via sponsor commitment, we will redeem 100% of the public shares at a per-share price equal to the aggregate amount on deposit in the trust account, including interest earned thereon (less taxes payable and up to $65,000 of interest to pay dissolution expenses), divided by the number of then outstanding public shares.
# Shareholders could face liability if distributions are deemed unlawful.

# %% [markdown]
# # **Stop Words**

# %%
stopwords = spacy.lang.en.stop_words.STOP_WORDS

# %%
stopwords
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
for sent in sents:
  print(sent.text)
  for token in sent:
    if token.text not in stopwords:
      print(token)
  break
# Out:
# If we are unable to complete our initial business combination within 33 months from the closing of this offering, unless we extend such period via sponsor commitment, we will redeem 100% of the public shares at a per-share price equal to the aggregate amount on deposit in the trust account, including interest earned thereon (less taxes payable and up to $65,000 of interest to pay dissolution expenses), divided by the number of then outstanding public shares.
# If
# unable
# complete
# initial
# business
# combination
# 33
# months
# closing
# offering
# ,
# extend
# period
# sponsor
# commitment
# ,
# redeem
# 100
# %
# public
# shares
# -
# share
# price
# equal
# aggregate
# deposit
# trust
# account
# ,
# including
# interest
# earned
# thereon
# (
# taxes
# payable
# $
# 65,000
# interest
# pay
# dissolution
# expenses
# )
# ,
# divided
# number
# outstanding
# public
# shares
# .

# %% [markdown]
# # Lemmatization

# %%
text = "playing played plays play"

# %%
doc = nlp(text)

# %%
# %%timeit
for token in doc:
  print(token.text, token.lemma_)
# Out:
# Streaming output truncated to the last 5000 lines.
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# play play
# playing playing
# played play
# plays play
# ...

# %% [markdown]
# # Stemming

# %%
# !pip install nltk

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
ps = PorterStemmer()

# %%
words = ["changing", "change", "changes", "changed", 'study', 'studying']

# %%
# %%timeit
for word in words:
  print(word, ":", ps.stem(word))
# Out:
# Streaming output truncated to the last 5000 lines.
# studying : studi
# changing : chang
# change : chang
# changes : chang
# changed : chang
# study : studi
# studying : studi
# changing : chang
# change : chang
# changes : chang
# changed : chang
# study : studi
# studying : studi
# changing : chang
# change : chang
# changes : chang
# changed : chang
# study : studi
# studying : studi
# changing : chang
# change : chang
# changes : chang
# changed : chang
# study : studi
# studying : studi
# changing : chang
# change : chang
# changes : chang
# changed : chang
# study : studi
# studying : studi
# changing : chang
# change : chang
# changes : chang
# changed : chang
# study : studi
# studying : studi
# changing : chang
# change : chang
# changes : chang
# changed : chang
# study : studi
# studying : studi
# changing : chang
# change : chang
# changes : chang
# changed : chang
# study : studi
# studying : studi
# changing : chang
# change : chang
# changes : chang
# changed : chang
# ...

# %% [markdown]
# # Word Frequency

# %%
text = "If we anticipate that we may not be able to consummate our initial business combination within 12 months from the effective date of this registration statement, we may, but are not obligated to, extend the period of time to consummate a business combination two times by an additional three months each time (for a total of up to 18 months to complete a business combination), provided that our sponsor or designee must deposit into the trust account for each three months extension, $600,000, or $690,000 if the underwriters’ over-allotment option is exercised in full ($0.10 per share in either case), up to an aggregate of $1,200,000 or $1,380,000 if the underwriters’ over-allotment option is exercised in full, on or prior to the date of the applicable deadline."

# %%
from collections import Counter

# %%
word_freq = Counter(text.split())
word_freq
# Out:
# Counter({'If': 1,
#          'we': 3,
#          'anticipate': 1,
#          'that': 2,
#          'may': 1,
#          'not': 2,
#          'be': 1,
#          'able': 1,
#          'to': 6,
#          'consummate': 2,
#          'our': 2,
#          'initial': 1,
#          'business': 3,
#          'combination': 2,
#          'within': 1,
#          '12': 1,
#          'months': 4,
#          'from': 1,
#          'the': 7,
#          'effective': 1,
#          'date': 2,
#          'of': 5,
#          'this': 1,
#          'registration': 1,
#          'statement,': 1,
#          'may,': 1,
#          'but': 1,
#          'are': 1,
#          'obligated': 1,
#          'to,': 1,
#          'extend': 1,
#          'period': 1,
#          'time': 2,
#          'a': 3,
#          'two': 1,
#          'times': 1,
#          'by': 1,
#          'an': 2,
#          'additional': 1,
#          'three': 2,
#          'each': 2,
#          '(for': 1,
#          'total': 1,
# ...

# %%
word_freq.most_common(5)
# Out:
# [('the', 7), ('to', 6), ('of', 5), ('months', 4), ('or', 4)]

# %%
doc = nlp(text)

# %%
words = [token.text for token in doc if not token.is_stop and not token.is_punct]

# %%
word_freq = Counter(words)
word_freq
# Out:
# Counter({'anticipate': 1,
#          'able': 1,
#          'consummate': 2,
#          'initial': 1,
#          'business': 3,
#          'combination': 3,
#          '12': 1,
#          'months': 4,
#          'effective': 1,
#          'date': 2,
#          'registration': 1,
#          'statement': 1,
#          'obligated': 1,
#          'extend': 1,
#          'period': 1,
#          'time': 2,
#          'times': 1,
#          'additional': 1,
#          'total': 1,
#          '18': 1,
#          'complete': 1,
#          'provided': 1,
#          'sponsor': 1,
#          'designee': 1,
#          'deposit': 1,
#          'trust': 1,
#          'account': 1,
#          'extension': 1,
#          '$': 5,
#          '600,000': 1,
#          '690,000': 1,
#          'underwriters': 2,
#          'allotment': 2,
#          'option': 2,
#          'exercised': 2,
#          '0.10': 1,
#          'share': 1,
#          'case': 1,
#          'aggregate': 1,
#          '1,200,000': 1,
# ...

# %% [markdown]
# # Token Matcher

# %%
from spacy.matcher import Matcher
from spacy.tokens import Span

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
matcher = Matcher(nlp.vocab)
